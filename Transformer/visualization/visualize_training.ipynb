# %%
import torch
import matplotlib.pyplot as plt
import os
import matplotlib.gridspec as gridspec
from visualization_utils import load_training_checkpoint, plot_training_metrics

# %%
checkpoint_path_1024_lr1e3 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_epoch_86_lr1e-3.pth"
checkpoint_path_512 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_512_epoch_58.pth"
checkpoint_path_256 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_256_epoch_19.pth"
checkpoint_path_512_lr1e5_2layer_2head_176ff = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_512_epoch_26_1e-5_2layer_2head_176ff.pth"
checkpoint_path_512_2layer_2head_176ff = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_512_epoch_39_2layer_2head_176ff.pth"
checkpoint_path_1024_lr1e5 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_epoch_19_lr1e-5.pth"
checkpoint_path_1024_2layer_2head = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_epoch_19_2layer_2head_176ff.pth"
checkpoint_path_256_2layer_2head_176ff = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_256_epoch_39_2layer_2head_176ff.pth"
checkpoint_path_256_lr1e5_2layer_2head_176ff = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_256_epoch_39_lr1e-5_2layer_2head_176ff.pth"
tester = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_256_epoch_26_4layer_1head_176ff.pth"
tester1 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_256_epoch_10_8layer_1head_176ff.pth"
tester2 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_256_epoch_39_2layer_2head_176ff_test.pth"

# checkpoint_path_512 = r"C:\Users\Gert\repos\CS2_cheat_detection\Transformer\checkpoints\model_512_epoch_99.pth"

metrics_1024_lr1e3 = load_training_checkpoint(checkpoint_path_1024_lr1e3)
metrics_1024_2layer_2head = load_training_checkpoint(checkpoint_path_1024_2layer_2head)
metrics_1024_lr1e5 = load_training_checkpoint(checkpoint_path_1024_lr1e5)
metrics_512 = load_training_checkpoint(checkpoint_path_512)
metrics_512_2layer_2head_176ff = load_training_checkpoint(checkpoint_path_512_2layer_2head_176ff)
metrics_512_lr1e5_2layer_2head_176ff = load_training_checkpoint(checkpoint_path_512_lr1e5_2layer_2head_176ff)
metrics_256 = load_training_checkpoint(checkpoint_path_256)
metrics_256_2layer_2head_176ff = load_training_checkpoint(checkpoint_path_256_2layer_2head_176ff)
metrics_256_lr1e5_2layer_2head_176ff = load_training_checkpoint(checkpoint_path_256_lr1e5_2layer_2head_176ff)
tester = load_training_checkpoint(tester)
tester1 = load_training_checkpoint(tester1)
tester2 = load_training_checkpoint(tester2)

# %%
plot_training_metrics(tester)
plot_training_metrics(tester1)
# plot_training_metrics(tester2)
plot_training_metrics(metrics_1024_lr1e3, "AntiCheatPT_1024_lr1e-3")
plot_training_metrics(metrics_1024_lr1e5, "AntiCheatPT_1024_lr1e-5")
plot_training_metrics(metrics_1024_2layer_2head, "AntiCheatPT_1024_2layer_2head_176ff")
plot_training_metrics(metrics_512, "AntiCheatPT_512")
plot_training_metrics(metrics_512_2layer_2head_176ff, "AntiCheatPT_512_2layer_2head_176ff")
plot_training_metrics(metrics_512_lr1e5_2layer_2head_176ff, "AntiCheatPT_512_lr1e-5_2layer_2head_176ff")
plot_training_metrics(metrics_256, "AntiCheatPT_256")
plot_training_metrics(metrics_256_2layer_2head_176ff, "AntiCheatPT_256_2layer_2head_176ff")
plot_training_metrics(metrics_256_lr1e5_2layer_2head_176ff, "AntiCheatPT_256_lr1e-5_2layer_2head_176ff")
