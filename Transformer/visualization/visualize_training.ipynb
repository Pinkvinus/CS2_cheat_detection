# %%
import torch
import matplotlib.pyplot as plt
import os
import matplotlib.gridspec as gridspec
from visualization_utils import load_training_checkpoint, plot_training_metrics

# %%
checkpoint_path_512 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_512_epoch_58.pth"
checkpoint_path_1024 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_epoch_85.pth"
# checkpoint_path_1024_seed41 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_seed41_epoch_39.pth"
# checkpoint_path_1024_seed43 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_seed43_epoch_39.pth"
checkpoint_path_1024_lr1e5 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_epoch_19_lr1e-5.pth"
# checkpoint_path_1024_lr1e3 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_epoch_86_lr1e-3.pth"
checkpoint_path_256 = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_256_epoch_19.pth"
checkpoint_path_256_2layer_2head_176ff = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_256_epoch_39_2layer_2head_176ff.pth"
checkpoint_path_512_lr1e5_2layer_2head_176ff = r"C:\Users\gluzk\source\repos\CS2_cheat_detection\Transformer\checkpoints\model_512_epoch_25_1e-5_2layer_2head_176ff.pth"

# checkpoint_path_512 = r"C:\Users\Gert\repos\CS2_cheat_detection\Transformer\checkpoints\model_512_epoch_99.pth"
# checkpoint_path_1024 = r"C:\Users\Gert\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_epoch_99.pth"
# checkpoint_path_1024_seed41 = r"C:\Users\Gert\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_seed41_epoch_39.pth"
# checkpoint_path_1024_seed43 = r"C:\Users\Gert\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_seed43_epoch_39.pth"
# checkpoint_path_1024_lr1e5 = r"C:\Users\Gert\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_epoch_39_lr1e-5.pth"
# checkpoint_path_1024_lr1e3 = r"C:\Users\Gert\repos\CS2_cheat_detection\Transformer\checkpoints\model_1024_epoch_99_lr1e-3.pth"

metrics_512 = load_training_checkpoint(checkpoint_path_512)
checkpoint = load_training_checkpoint(checkpoint_path_1024_lr1e5)
metrics_1024 = load_training_checkpoint(checkpoint_path_1024)
# metrics_1024_seed43 = load_training_checkpoint(checkpoint_path_1024_seed43)
# metrics_1024_seed41 = load_training_checkpoint(checkpoint_path_1024_seed41)
# metrics_1024_lr1e5 = load_training_checkpoint(checkpoint_path_1024_lr1e5)
# metrics_1024_lr1e3 = load_training_checkpoint(checkpoint_path_1024_lr1e3)
metrics_256 = load_training_checkpoint(checkpoint_path_256)
metrics_256_2layer_2head_176ff = load_training_checkpoint(checkpoint_path_256_2layer_2head_176ff)
metrics_512_lr1e5_2layer_2head_176ff = load_training_checkpoint(checkpoint_path_512_lr1e5_2layer_2head_176ff)

# %%
plot_training_metrics(metrics_1024, "AntiCheatPT_1024")
# plot_training_metrics(metrics_1024_seed41, "AntiCheatPT_Seed_41")
# plot_training_metrics(metrics_1024_seed43, "AntiCheatPT_Seed_43")
# plot_training_metrics(metrics_1024_lr1e5, "AntiCheatPT_lr1e-5")
# plot_training_metrics(metrics_1024_lr1e3, "AntiCheatPT_lr1e-3")
plot_training_metrics(checkpoint, "AntiCheatPT_1025_lr1e-5")
plot_training_metrics(metrics_256, "AntiCheatPT_256")
plot_training_metrics(metrics_256_2layer_2head_176ff, "AntiCheatPT_256_2layer_2head_176ff")
plot_training_metrics(metrics_512, "AntiCheatPT_512")
plot_training_metrics(metrics_512_lr1e5_2layer_2head_176ff, "AntiCheatPT_512_lr1e5_2layer_2head_176ff")
